# %%
import pandas as pd

# %%
fires_carrer =pd.read_csv0(r"C:\Users\34626\Documents\TRABAJO\TALENTO DIGITAL\hackaton\fires_carrer.csv"
                            , sep=',', encoding = 'utf-16')

# %%
mercats_municipals= pd.read_csv (r"C:\Users\34626\Documents\TRABAJO\TALENTO DIGITAL\hackaton\mercats_municipals.csv"
                            , sep=',', encoding = 'utf-16')

# %%
centres_comercials = pd.read_csv(r"C:\Users\34626\Documents\TRABAJO\TALENTO DIGITAL\hackaton\centres comercials.csv"
                            , sep=',', encoding = 'utf-16')

# %%
galeries = pd.read_csv(r"C:\Users\34626\Documents\TRABAJO\TALENTO DIGITAL\hackaton\galeries_comercials.csv"
                            , sep=',', encoding = 'utf-16')

# %%
barris_fc=fires_carrer['addresses_neighborhood_id'].value_counts()
barris_fc = barris_fc.rename_axis('barri').reset_index(name='num_FC')

# %%
barris_mm=mercats_municipals['addresses_neighborhood_id'].value_counts()
barris_mm = barris_mm.rename_axis('barri').reset_index(name='num_MM')

# %%
barris_cc = centres_comercials['addresses_neighborhood_id'].value_counts()

# Asignar nombre a la columna
barris_cc = barris_cc.rename_axis('barri').reset_index(name='num_CC')

# %%
barris_gc = galeries['addresses_neighborhood_id'].value_counts()
barris_gc = barris_gc.rename_axis('barri').reset_index(name='num_GC')

# %%
barris_1= pd.merge(barris_fc, barris_mm, on='barri', how='outer')

# %%
barris_2= pd.merge(barris_cc, barris_gc, on='barri', how='outer')

# %%
comerbarris = pd.merge(barris_1, barris_2, on='barri', how='outer')

# %%
comerbarris
# Out:
#     barri  num_FC  num_MM  num_CC  num_GC
# 0       2     7.0     2.0     3.0     1.0
# 1      19     4.0     2.0     4.0     NaN
# 2      23     4.0     2.0     NaN     NaN
# 3      10     4.0     5.0     NaN     NaN
# 4       4     3.0     1.0     NaN     NaN
# 5      60     2.0     1.0     NaN     NaN
# 6       1     2.0     1.0     NaN     NaN
# 7       5     2.0     3.0     NaN     NaN
# 8      25     2.0     1.0     NaN     NaN
# 9      48     2.0     1.0     NaN     NaN
# 10      6     2.0     1.0     NaN     1.0
# 11     55     2.0     2.0     NaN     NaN
# 12     64     1.0     NaN     NaN     NaN
# 13     49     1.0     1.0     NaN     NaN
# 14      3     1.0     1.0     NaN     NaN
# 15     68     1.0     1.0     NaN     NaN
# 16     65     1.0     1.0     NaN     NaN
# 17     72     1.0     1.0     NaN     NaN
# 18     12     1.0     NaN     NaN     NaN
# 19     53     1.0     2.0     NaN     NaN
# 20     43     1.0     1.0     NaN     NaN
# 21     18     1.0     1.0     NaN     NaN
# 22     70     1.0     1.0     NaN     NaN
# 23     32     NaN     2.0     NaN     NaN
# 24      7     NaN     2.0     4.0     1.0
# 25     35     NaN     1.0     NaN     NaN
# 26      8     NaN     1.0     NaN     NaN
# 27     30     NaN     1.0     NaN     NaN
# 28     31     NaN     1.0     NaN     NaN
# 29     37     NaN     1.0     NaN     NaN
# 30     61     NaN     1.0     1.0     NaN
# 31     50     NaN     1.0     NaN     NaN
# 32     59     NaN     1.0     3.0     NaN
# 33     73     NaN     1.0     NaN     NaN
# 34     46     NaN     1.0     NaN     NaN
# 35     38     NaN     1.0     NaN     NaN
# 36     24     NaN     1.0     NaN     NaN
# 37     26     NaN     1.0     NaN     NaN
# 38     13     NaN     1.0     2.0     NaN
# 39     15     NaN     1.0     NaN     NaN
# 40     66     NaN     NaN     3.0     NaN
# 41     45     NaN     NaN     2.0     NaN
# 42     69     NaN     NaN     2.0     NaN
# 43      9     NaN     NaN     2.0     NaN
# 44     67     NaN     NaN     1.0     NaN
# 45     28     NaN     NaN     NaN     1.0

# %%
fires_carrer[['addresses_neighborhood_id', 'addresses_neighborhood_name']]
# Out:
#     addresses_neighborhood_id            addresses_neighborhood_name
# 0                          48                           la Guineueta
# 1                           2                         el Barri Gòtic
# 2                           6                     la Sagrada Família
# 3                           2                         el Barri Gòtic
# 4                           2                         el Barri Gòtic
# 5                          23                                 Sarrià
# 6                          12             la Marina del Prat Vermell
# 7                           2                         el Barri Gòtic
# 8                          23                                 Sarrià
# 9                           4  Sant Pere, Santa Caterina i la Ribera
# 10                         72               Sant Martí de Provençals
# 11                         23                                 Sarrià
# 12                          3                         la Barceloneta
# 13                         49                              Canyelles
# 14                         60                            Sant Andreu
# 15                         64             el Camp de l'Arpa del Clot
# 16                         55                       Ciutat Meridiana
# 17                          4  Sant Pere, Santa Caterina i la Ribera
# 18                         25             Sant Gervasi - la Bonanova
# 19                         48                           la Guineueta
# 20                         68                            el Poblenou
# 21                         65                                el Clot
# 22                         10                            Sant Antoni
# 23                         10                            Sant Antoni
# 24                          5                          el Fort Pienc
# 25                          5                          el Fort Pienc
# 26                         55                       Ciutat Meridiana
# 27                         53                       la Trinitat Nova
# 28                          6                     la Sagrada Família
# 29                         23                                 Sarrià
# 30                          2                         el Barri Gòtic
# 31                         43                                  Horta
# 32                          4  Sant Pere, Santa Caterina i la Ribera
# 33                         25             Sant Gervasi - la Bonanova
# 34                         18                                  Sants
# 35                          1                               el Raval
# 36                         70                  el Besòs i el Maresme
# 37                         19                              les Corts
# 38                         60                            Sant Andreu
# 39                         19                              les Corts
# 40                          2                         el Barri Gòtic
# 41                          2                         el Barri Gòtic
# 42                         10                            Sant Antoni
# 43                         10                            Sant Antoni
# 44                          1                               el Raval
# 45                         19                              les Corts
# 46                         19                              les Corts

# %%
nom_barris = fires_carrer[['addresses_neighborhood_id', 'addresses_neighborhood_name']].drop_duplicates()

# %%
nom_barris.columns = ['barri', 'nom']
nom_barris
# Out:
#     barri                                    nom
# 0      48                           la Guineueta
# 1       2                         el Barri Gòtic
# 2       6                     la Sagrada Família
# 5      23                                 Sarrià
# 6      12             la Marina del Prat Vermell
# 9       4  Sant Pere, Santa Caterina i la Ribera
# 10     72               Sant Martí de Provençals
# 12      3                         la Barceloneta
# 13     49                              Canyelles
# 14     60                            Sant Andreu
# 15     64             el Camp de l'Arpa del Clot
# 16     55                       Ciutat Meridiana
# 18     25             Sant Gervasi - la Bonanova
# 20     68                            el Poblenou
# 21     65                                el Clot
# 22     10                            Sant Antoni
# 24      5                          el Fort Pienc
# 27     53                       la Trinitat Nova
# 31     43                                  Horta
# 34     18                                  Sants
# 35      1                               el Raval
# 36     70                  el Besòs i el Maresme
# 37     19                              les Corts

# %%
comerbarris_nom = pd.merge(comerbarris, nom_barris,  on='barri', how='inner')
comerbarris_nom.fillna(0, inplace=True)

# %%
comerbarris_nom
# Out:
#     barri  num_FC  num_MM  num_CC  num_GC  \
# 0       2     7.0     2.0     3.0     1.0
# 1      19     4.0     2.0     4.0     0.0
# 2      23     4.0     2.0     0.0     0.0
# 3      10     4.0     5.0     0.0     0.0
# 4       4     3.0     1.0     0.0     0.0
# 5      60     2.0     1.0     0.0     0.0
# 6       1     2.0     1.0     0.0     0.0
# 7       5     2.0     3.0     0.0     0.0
# 8      25     2.0     1.0     0.0     0.0
# 9      48     2.0     1.0     0.0     0.0
# 10      6     2.0     1.0     0.0     1.0
# 11     55     2.0     2.0     0.0     0.0
# 12     64     1.0     0.0     0.0     0.0
# 13     49     1.0     1.0     0.0     0.0
# 14      3     1.0     1.0     0.0     0.0
# 15     68     1.0     1.0     0.0     0.0
# 16     65     1.0     1.0     0.0     0.0
# 17     72     1.0     1.0     0.0     0.0
# 18     12     1.0     0.0     0.0     0.0
# 19     53     1.0     2.0     0.0     0.0
# 20     43     1.0     1.0     0.0     0.0
# 21     18     1.0     1.0     0.0     0.0
# 22     70     1.0     1.0     0.0     0.0
#
#                                       nom
# 0                          el Barri Gòtic
# 1                               les Corts
# 2                                  Sarrià
# 3                             Sant Antoni
# 4   Sant Pere, Santa Caterina i la Ribera
# 5                             Sant Andreu
# 6                                el Raval
# 7                           el Fort Pienc
# 8              Sant Gervasi - la Bonanova
# 9                            la Guineueta
# 10                     la Sagrada Família
# 11                       Ciutat Meridiana
# 12             el Camp de l'Arpa del Clot
# 13                              Canyelles
# 14                         la Barceloneta
# 15                            el Poblenou
# 16                                el Clot
# 17               Sant Martí de Provençals
# 18             la Marina del Prat Vermell
# 19                       la Trinitat Nova
# 20                                  Horta
# 21                                  Sants
# 22                  el Besòs i el Maresme

# %%
import matplotlib.pyplot as plt
import seaborn as sns
